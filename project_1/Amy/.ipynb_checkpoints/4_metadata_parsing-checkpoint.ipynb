# %% [markdown]
# # Import

# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %% [markdown]
# # Load Files

# %%
# Load File
DATA_PATH = Path('../../Data/')
data = pd.read_csv(Path(DATA_PATH, 'processed/TCGA.HNSC.expression_log_all.txt.zip'), sep = '\t', compression='zip').fillna("NaN")
metadata = pd.read_csv(Path(DATA_PATH, 'original/TCGA.HNSC.metadata.txt'), sep = '\t').fillna("NaN")

# %% [markdown]
# # metadata of samples

# %% [markdown]
# original information from patient metadata df

# %%
metadata_sample = pd.DataFrame({
    'patient_id': data[' patient_id'].values
}, index=data['sample_id'])
metadata_sample.index.name = 'sample_id'

# %%
metadata_sample = metadata_sample.reset_index().merge(
    metadata, left_on='patient_id', right_on='patient_id', how='left'
).set_index('sample_id')

# %% [markdown]
# sample_id information

# %%
# tissue source site
tss = pd.read_csv(Path(DATA_PATH, 'tcga_code_tables/tissueSourceSite.tsv'), sep = '\t').fillna("NaN")
metadata_sample['TSS_code'] = metadata_sample.index.str.split('-').str[1]
metadata_sample = metadata_sample.reset_index().merge(
    tss, left_on='TSS_code', right_on='TSS Code', how='left'
).set_index('sample_id')
metadata_sample = metadata_sample.drop(columns=['TSS_code', 'TSS Code', 'Study Name'], errors='ignore')

# %%
# sample type
st = pd.read_csv(Path(DATA_PATH, 'tcga_code_tables/sampleType.tsv'), sep = '\t').fillna("NaN")
metadata_sample['ST'] = metadata_sample.index.str.split('-').str[3].str[:2].astype(str).astype(int)
metadata_sample = metadata_sample.reset_index().merge(
    st, left_on='ST', right_on='Code', how='left'
).set_index('sample_id')
metadata_sample = metadata_sample.drop(columns=['ST', 'Code', 'Short Letter Code'], errors='ignore')
metadata_sample = metadata_sample.rename(columns={'Definition': 'sample_type'})

# %% [markdown]
# additional metadata from paper

# %%
HPDF = pd.read_csv(Path(DATA_PATH, 'Original_paper_files/1.1_HNSC_Patient_Data_Freeze.tsv'), sep = '\t').fillna("NaN")
HP = pd.read_csv(Path(DATA_PATH, 'Original_paper_files/1.1_HNSC_Patient.tsv'), sep = '\t').fillna("NaN")
HP_all = pd.concat([HPDF, HP]).drop_duplicates(subset='bcr_patient_barcode', keep='first')
cols_to_add = [
    'bcr_patient_barcode',
    'ajcc_clinical_group_stage', 'ajcc_clinical_primary_tumor_t_stage',
    'ajcc_clinical_primary_tumor_n_stage', 'ajcc_clinical_primary_tumor_m_stage',
    'tumor_stage', 'primary_therapy_outcome_success',
    'radiation_therapy', 'postoperative_rx_tx', 'history_of_neoadjuvant_treatment',
    'hpv_status_by_ish_testing', 'hpv_status_by_p16_testing',
    'number_pack_years_smoked', 'tobacco_smoking_history_indicator',
    'alcohol_history_documented', 'frequency_of_alcohol_consumption',
    'amount_of_alcohol_consumption_per_day', 'p53_gene_analysis',
    'egfr_amplication_status'
]
metadata_sample = metadata_sample.reset_index().merge(
    HP_all[cols_to_add],
    left_on='patient_id',
    right_on='bcr_patient_barcode',
    how='left'
).set_index('sample_id')

# %% [markdown]
# # Output enriched metadata

# %%
HP_all = pd.concat([HPDF, HP]).drop_duplicates(subset='bcr_patient_barcode', keep='first')
metadata_sample = metadata_sample.reset_index().merge(
    HP_all[cols_to_add],
    left_on='patient_id',
    right_on='bcr_patient_barcode',
    how='left'
).set_index('sample_id')

# %%
HP_all
# Out:
#     bcr_patient_barcode age_at_initial_pathologic_diagnosis  \
# 0          TCGA-BA-4074                                  69
# 1          TCGA-BA-4076                                  39
# 2          TCGA-BA-4077                                  45
# 3          TCGA-BA-4078                                  83
# 4          TCGA-BA-5149                                  47
# ..                  ...                                 ...
# 305        TCGA-H7-8502                         [Completed]
# 311        TCGA-HD-7917                                  62
# 312        TCGA-HD-8224                                  63
# 313        TCGA-HD-8314                                  58
# 314        TCGA-HL-7533                                  65
#
#     ajcc_cancer_staging_handbook_edition ajcc_clinical_group_stage  \
# 0                                    6th                 Stage IVA
# 1                                    6th                 Stage IVA
# 2                                    6th                 Stage IVB
# 3                                    6th                 Stage IVA
# 4                                    7th                 Stage IVA
# ..                                   ...                       ...
# 305                                  7th                 Stage IVA
# 311                                  7th                  Stage II
# 312                                  7th                 Stage III
# 313                                  7th                 Stage III
# 314                                  6th                 Stage IVA
#
#     ajcc_clinical_primary_tumor_m_stage ajcc_clinical_primary_tumor_n_stage  \
# 0                                    M0                                 N2c
# 1                                    M0                                 N2c
# 2                                    M0                                  N3
# 3                                    M0                                 N2a
# 4                                    M0                                 N2b
# ..                                  ...                                 ...
# 305                                  MX                                 N2b
# 311                                  M0                                  N0
# 312                                  M0                                  N0
# 313                                  M0                                  N1
# 314                                  M0                                 N2b
#
#     ajcc_clinical_primary_tumor_t_stage alcohol_history_documented  \
# 0                                    T3                        YES
# 1                                    T3                        YES
# 2                                   T4b                        YES
# 3                                    T2                         NO
# 4                                    T3                        YES
# ..                                  ...                        ...
# 305                                 T4a                        YES
# 311                                  T2                        YES
# 312                                  T3                        YES
# 313                                  T1                         NO
# 314                                  T2                        YES
#
#     amount_of_alcohol_consumption_per_day anatomic_organ_subdivision  ...  \
# 0                                     NaN                        NaN  ...
# 1                                     NaN                        NaN  ...
# 2                                     0.0                        NaN  ...
# 3                                     NaN                        NaN  ...
# 4                                     7.0                        NaN  ...
# ..                                    ...                        ...  ...
# 305                                     8            [Not Available]  ...
# 311                                    12            [Not Available]  ...
# 312                                     5            [Not Available]  ...
# 313                       [Not Available]            [Not Available]  ...
# 314                                   2.5            [Not Available]  ...
#
#       race radiation_therapy stopped_smoking_year  \
# 0    WHITE               NaN                  NaN
# 1    WHITE               NaN                  NaN
# 2    WHITE               NaN               2005.0
# 3    WHITE               NaN               1994.0
# 4    WHITE               NaN                  NaN
# ..     ...               ...                  ...
# 305  WHITE               YES      [Not Available]
# 311  WHITE   [Not Available]      [Not Available]
# 312  WHITE   [Not Available]      [Not Available]
# 313  WHITE                NO      [Not Available]
# 314  WHITE   [Not Available]                 1988
#
#     tissue_prospective_collection_indicator  \
# 0                                        NO
# 1                                        NO
# 2                                        NO
# 3                                        NO
# 4                                       YES
# ..                                      ...
# 305                                     YES
# 311                                     YES
# 312                                     YES
# 313                                     YES
# 314                                      NO
#
#     tissue_retrospective_collection_indicator tissue_source_site  \
# 0                                         YES                 BA
# 1                                         YES                 BA
# 2                                         YES                 BA
# 3                                         YES                 BA
# 4                                          NO                 BA
# ..                                        ...                ...
# 305                                        NO                 H7
# 311                                        NO                 HD
# 312                                        NO                 HD
# 313                                        NO                 HD
# 314                                       YES                 HL
#
#                tobacco_smoking_history_indicator      tumor_stage  \
# 0                                 Current smoker        Stage IVA
# 1                                 Current smoker              NaN
# 2    Current reformed smoker for < or = 15 years        Stage IVA
# 3    Current reformed smoker for < or = 15 years              NaN
# 4                                 Current smoker        Stage IVA
# ..                                           ...              ...
# 305                               Current smoker        Stage IVA
# 311                               Current smoker         Stage II
# 312                          Lifelong Non-smoker        Stage IVA
# 313                          Lifelong Non-smoker        Stage III
# 314       Current reformed smoker for > 15 years  [Not Available]
#
#     tumor_tissue_site vital_status
# 0           HEAD/NECK     DECEASED
# 1           HEAD/NECK     DECEASED
# 2           HEAD/NECK     DECEASED
# 3           HEAD/NECK     DECEASED
# 4           HEAD/NECK       LIVING
# ..                ...          ...
# 305         HEAD/NECK       LIVING
# 311         HEAD/NECK       LIVING
# 312         HEAD/NECK       LIVING
# 313         HEAD/NECK       LIVING
# 314         HEAD/NECK       LIVING
#
# [318 rows x 67 columns]
