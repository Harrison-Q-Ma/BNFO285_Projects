# %%
import pandas as pd

# %%
metadata = pd.read_csv("/Users/clairez/Desktop/BNFO285_Projects/Data/processed/processed_metadata.txt", sep="\t", header=0)
metadata
# Out:
#        patient_id   age   OS  OS_time  DSS  DSS_time  DFI  DFI_time  gender  \
# 0    TCGA-4P-AA8J  66.0  0.0    102.0  0.0     102.0  NaN       NaN    MALE
# 1    TCGA-BA-4074  69.0  1.0    462.0  1.0     462.0  NaN       NaN    MALE
# 2    TCGA-BA-4075  49.0  1.0    283.0  1.0     283.0  NaN       NaN    MALE
# 3    TCGA-BA-4076  39.0  1.0    415.0  1.0     415.0  NaN       NaN    MALE
# 4    TCGA-BA-4077  45.0  1.0   1134.0  1.0    1134.0  NaN       NaN  FEMALE
# ..            ...   ...  ...      ...  ...       ...  ...       ...     ...
# 495  TCGA-UF-A7JT  72.0  1.0    993.0  1.0     993.0  NaN       NaN  FEMALE
# 496  TCGA-UF-A7JV  62.0  1.0     90.0  1.0      90.0  NaN       NaN  FEMALE
# 497  TCGA-UP-A6WW  58.0  0.0    518.0  0.0     518.0  NaN       NaN    MALE
# 498  TCGA-WA-A7GZ  58.0  1.0    625.0  0.0     625.0  0.0     625.0    MALE
# 499  TCGA-WA-A7H4  69.0  0.0    443.0  0.0     443.0  0.0     443.0    MALE
#
#       tumor_site tumor_class tumor_stage hpv_status
# ...

# %%
metadata["tumor_stage"].unique()
stage_map = {
    "Stage 0": "0",
    "Stage I": "1",
    "Stage II": "2",
    "Stage III": "3",
    "Stage IVA": "4",
    "Stage IVB": "4",
    "Stage IVC": "4",
}
metadata["tumor_stage"] = metadata["tumor_stage"].map(stage_map)
metadata["tumor_stage"].unique()
# Out:
# array(['4', '3', nan, '2', '1', '0'], dtype=object)

# %%
metadata.loc[metadata["tumor_class"] == "metastasis", "tumor_stage"] = "4"
metadata
# Out:
#        patient_id   age   OS  OS_time  DSS  DSS_time  DFI  DFI_time  gender  \
# 0    TCGA-4P-AA8J  66.0  0.0    102.0  0.0     102.0  NaN       NaN    MALE
# 1    TCGA-BA-4074  69.0  1.0    462.0  1.0     462.0  NaN       NaN    MALE
# 2    TCGA-BA-4075  49.0  1.0    283.0  1.0     283.0  NaN       NaN    MALE
# 3    TCGA-BA-4076  39.0  1.0    415.0  1.0     415.0  NaN       NaN    MALE
# 4    TCGA-BA-4077  45.0  1.0   1134.0  1.0    1134.0  NaN       NaN  FEMALE
# ..            ...   ...  ...      ...  ...       ...  ...       ...     ...
# 495  TCGA-UF-A7JT  72.0  1.0    993.0  1.0     993.0  NaN       NaN  FEMALE
# 496  TCGA-UF-A7JV  62.0  1.0     90.0  1.0      90.0  NaN       NaN  FEMALE
# 497  TCGA-UP-A6WW  58.0  0.0    518.0  0.0     518.0  NaN       NaN    MALE
# 498  TCGA-WA-A7GZ  58.0  1.0    625.0  0.0     625.0  0.0     625.0    MALE
# 499  TCGA-WA-A7H4  69.0  0.0    443.0  0.0     443.0  0.0     443.0    MALE
#
#       tumor_site tumor_class tumor_stage hpv_status
# ...

# %%
metadata.to_csv(
    "/Users/clairez/Desktop/BNFO285_Projects/Data/processed/processed_metadata.txt",
    sep="\t",
    index=False,
    header=True
)
