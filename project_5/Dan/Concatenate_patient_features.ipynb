# %%
import pandas as pd
import numpy as np

# %%
patients = pd.read_csv('/cellar/users/dhalmos/class/BNFO285/BNFO285_Projects/project_5/Amy/patients.txt', header = None)
mutations = pd.read_csv('/cellar/users/dhalmos/class/BNFO285/BNFO285_Projects/project_5/Dan/train_mutation_embedding.csv')
expression = pd.read_csv('/cellar/users/dhalmos/class/BNFO285/BNFO285_Projects/project_5/Harrison/PCA_subset.tsv', sep = '\t')
cnvs = pd.read_csv('/cellar/users/dhalmos/class/BNFO285/BNFO285_Projects/project_5/Wenshu/CNV_features.tsv', sep = '\t')

# %%
expression
# Out:
#        patient_id        PC1        PC2        PC3        PC4        PC5  \
# 0    TCGA-4P-AA8J  26.598411 -22.877210  -0.578889   1.355819  14.338859
# 1    TCGA-BA-4074 -12.167557 -34.067932  -6.116876 -12.142741   2.158705
# 2    TCGA-BA-4075  -4.536258 -39.425484 -10.844956 -20.751842   2.805745
# 3    TCGA-BA-4076 -27.484337  10.899081 -25.749578  -4.556297  -6.865086
# 4    TCGA-BA-4077  -1.579689   2.466259   3.903651   7.498580  10.952675
# ..            ...        ...        ...        ...        ...        ...
# 382  TCGA-UF-A7JT  -7.117704   0.532719 -26.821629  -9.491319  14.561163
# 383  TCGA-UP-A6WW -26.020624 -15.684109  19.663563 -24.086077   7.332528
# 384  TCGA-WA-A7GZ  20.357235   1.099707 -13.116333   4.412999  -9.034357
# 385  TCGA-WA-A7GZ  70.726808  28.765358  45.047537 -29.244817 -27.901091
# 386  TCGA-WA-A7H4  34.198218 -15.277586  23.949386  20.427531  26.902581
#
#            PC6        PC7        PC8        PC9  ...      PC27       PC28  \
# ...

# %%
cnvs
# Out:
#        patient_id  WDR5
# 0    TCGA-4P-AA8J     0
# 1    TCGA-BA-4074     0
# 2    TCGA-BA-4075     0
# 3    TCGA-BA-4076     0
# 4    TCGA-BA-4077     1
# ..            ...   ...
# 343  TCGA-UF-A7JS     1
# 344  TCGA-UF-A7JT     1
# 345  TCGA-UP-A6WW     1
# 346  TCGA-WA-A7GZ     0
# 347  TCGA-WA-A7H4     0
#
# [348 rows x 2 columns]

# %%
mutations
# Out:
#        patient_id  LRP1B   FAT1  PIK3CA  PTPRD  FBXW7   TP53  CDKN2A  NFE2L2  \
# 0    TCGA-4P-AA8J   True  False   False  False  False  False   False   False
# 1    TCGA-BA-4075  False  False   False  False  False  False   False   False
# 2    TCGA-BA-4076  False  False   False  False  False   True   False   False
# 3    TCGA-BA-4076  False  False   False  False  False  False   False   False
# 4    TCGA-BA-4077  False  False    True  False  False  False   False   False
# ..            ...    ...    ...     ...    ...    ...    ...     ...     ...
# 290  TCGA-UF-A7JF  False  False    True  False  False  False   False   False
# 291  TCGA-UF-A7JO  False  False   False  False  False   True   False   False
# 292  TCGA-UF-A7JO  False  False   False  False   True  False   False   False
# 293  TCGA-UF-A7JS  False  False   False  False  False   True   False   False
# 294  TCGA-WA-A7GZ  False  False   False  False  False   True   False   False
#
#       RELN  NOTCH1
# 0    False   False
# ...
